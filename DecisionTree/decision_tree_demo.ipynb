# %%
import pandas as pd
import numpy as numpy

# %%
pd.read_csv("http://biostat.mc.vanderbilt.edu/wiki/pub/Main/DataSets/titainc.txt")
# Out:
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# d:\program files\anaconda3\envs\use_conda\lib\urllib\request.py in do_open(self, http_class, req, **http_conn_args)
#    1349                 h.request(req.get_method(), req.selector, req.data, headers,
# -> 1350                           encode_chunked=req.has_header('Transfer-encoding'))
#    1351             except OSError as err: # timeout error
#
# d:\program files\anaconda3\envs\use_conda\lib\http\client.py in request(self, method, url, body, headers, encode_chunked)
#    1276         """Send a complete request to the server."""
# -> 1277         self._send_request(method, url, body, headers, encode_chunked)
#    1278
#
# d:\program files\anaconda3\envs\use_conda\lib\http\client.py in _send_request(self, method, url, body, headers, encode_chunked)
#    1322             body = _encode(body, 'body')
# ...
